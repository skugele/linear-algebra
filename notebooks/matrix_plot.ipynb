# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from linear_algebra.matrix_plot import *

# %%
m = np.column_stack([[2,0],[1,-7],[-5,10],[3,4],[1,15]])
plot_colspace_2d(m)

# %%
m = np.random.rand(2,20)
t = np.column_stack([[-1,0],[0,-1]])
plot_colspace_transform_2d(m, t)
